# %% [markdown]
# # **1. Data cleaning**

# %%
import pandas as pd

# %%
df_2015 = pd.read_csv("Raw_Datasets/2015.csv")

df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2015.columns = df_2015.columns.str.lower()
df_2015.columns
# Out:
# Index(['country', 'region', 'happiness rank', 'happiness score',
#        'standard error', 'economy (gdp per capita)', 'family',
#        'health (life expectancy)', 'freedom', 'trust (government corruption)',
#        'generosity', 'dystopia residual'],
#       dtype='object')

# %%
df_2015 = df_2015.rename(columns={
    "happiness rank" : "happiness_rank",
    "happiness score" : "happiness_score",
    "standard error": "standard_error",
    "economy (gdp per capita)" : "gdp_per_capita",
    "health (life expectancy)" : "life_expectancy",
    "trust (government corruption)": "government_corruption",
    "dystopia residual" : "dystopia_residual"
})

df_2015.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard_error  gdp_per_capita   family  life_expectancy  freedom  \
# 0         0.03411         1.39651  1.34951          0.94143  0.66557
# 1         0.04884         1.30232  1.40223          0.94784  0.62877
# 2         0.03328         1.32548  1.36058          0.87464  0.64938
# 3         0.03880         1.45900  1.33095          0.88521  0.66973
# 4         0.03553         1.32629  1.32261          0.90563  0.63297
#
#    government_corruption  generosity  dystopia_residual
# 0                0.41978     0.29678            2.51738
# 1                0.14145     0.43630            2.70201
# 2                0.48357     0.34139            2.49204
# 3                0.36503     0.34699            2.46531
# 4                0.32957     0.45811            2.45176

# %%
null_values_2015 = df_2015.isnull().sum()
null_values_2015
# Out:
# country                  0
# region                   0
# happiness_rank           0
# happiness_score          0
# standard_error           0
# gdp_per_capita           0
# family                   0
# life_expectancy          0
# freedom                  0
# government_corruption    0
# generosity               0
# dystopia_residual        0
# dtype: int64

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
safe_df_2015 = df_2015.copy()

# %%
df_2016 = pd.read_csv("Raw_Datasets/2016.csv")
print(df_2016.head())

null_values_2016 = df_2016.isnull().sum()
null_values_2016
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
safe_df_2016 = df_2016.copy()

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2016 = df_2016.rename(columns={
    "Country" : "country",
    "Region" : "region",
    "Happiness Rank" : "happiness_rank",
    "Happiness Score" : "happiness_score",
    "Lower Confidence Interval" : "lower_confidence_interval",
    "Upper Confidence Interval" : "upper_confidence_interval",
    "Economy (GDP per Capita)" : "gdp_per_capita",
    "Family" : "family",
    "Health (Life Expectancy)" : "life_expectancy",
    "Freedom" : "freedom",
    "Trust (Government Corruption)": "government_corruption",
    "Generosity": "generosity",
    "Dystopia Residual" : "dystopia_residual"
})

df_2016.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    lower_confidence_interval  upper_confidence_interval  gdp_per_capita  \
# 0                      7.460                      7.592         1.44178
# 1                      7.428                      7.590         1.52733
# 2                      7.333                      7.669         1.42666
# 3                      7.421                      7.575         1.57744
# 4                      7.351                      7.475         1.40598
#
#     family  life_expectancy  freedom  government_corruption  generosity  \
# 0  1.16374          0.79504  0.57941                0.44453     0.36171
# 1  1.14524          0.86303  0.58557                0.41203     0.28083
# 2  1.18326          0.86733  0.56624                0.14975     0.47678
# 3  1.12690          0.79579  0.59609                0.35776     0.37895
# 4  1.13464          0.81091  0.57104                0.41004     0.25492
#
#    dystopia_residual
# 0            2.73939
# 1            2.69463
# 2            2.83137
# 3            2.66465
# 4            2.82596

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2017 = pd.read_csv("Raw_Datasets/2017.csv")
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
safe_df_2017 = df_2017.copy()

# %%
df_2017 = df_2017.rename(columns={
    "Country" : "country",
    "Happiness.Rank" : "happiness_rank",
    "Happiness.Score" : "happiness_score",
    "Whisker.high" : "whisker.high",
    "Whisker.low" : "whisker.low",
    "Economy..GDP.per.Capita." : "gdp_per_capita",
    "Family" : "family",
    "Health..Life.Expectancy." : "life_expectancy",
    "Freedom" : "freedom",
    "Trust..Government.Corruption.": "government_corruption",
    "Generosity": "generosity",
    "Dystopia.Residual" : "dystopia_residual"
})

df_2017.head()
# Out:
#        country  happiness_rank  happiness_score  whisker.high  whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    gdp_per_capita    family  life_expectancy   freedom  generosity  \
# 0        1.616463  1.533524         0.796667  0.635423    0.362012
# 1        1.482383  1.551122         0.792566  0.626007    0.355280
# 2        1.480633  1.610574         0.833552  0.627163    0.475540
# 3        1.564980  1.516912         0.858131  0.620071    0.290549
# 4        1.443572  1.540247         0.809158  0.617951    0.245483
#
#    government_corruption  dystopia_residual
# 0               0.315964           2.277027
# 1               0.400770           2.313707
# 2               0.153527           2.322715
# 3               0.367007           2.276716
# 4               0.382612           2.430182

# %%
null_values_2017 = df_2017.isnull().sum()
null_values_2017
# Out:
# country                  0
# happiness_rank           0
# happiness_score          0
# whisker.high             0
# whisker.low              0
# gdp_per_capita           0
# family                   0
# life_expectancy          0
# freedom                  0
# generosity               0
# government_corruption    0
# dystopia_residual        0
# dtype: int64

# %%
df_2018 = pd.read_csv("Raw_Datasets/2018.csv")
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
safe_df_2018 = df_2018.copy()

# %%
df_2018 = df_2018.rename(columns={
    "Country or region" : "country",
    "Overall rank" : "happiness_rank",
    "Score" : "happiness_score",
    "GDP per capita" : "gdp_per_capita",
    "Social support" : "family",
    "Healthy life expectancy" : "life_expectancy",
    "Freedom to make life choices" : "freedom",
    "Perceptions of corruption": "government_corruption",
    "Generosity": "generosity",
})

df_2018.head()
# Out:
#    happiness_rank      country  happiness_score  gdp_per_capita  family  \
# 0               1      Finland            7.632           1.305   1.592
# 1               2       Norway            7.594           1.456   1.582
# 2               3      Denmark            7.555           1.351   1.590
# 3               4      Iceland            7.495           1.343   1.644
# 4               5  Switzerland            7.487           1.420   1.549
#
#    life_expectancy  freedom  generosity  government_corruption
# 0            0.874    0.681       0.202                  0.393
# 1            0.861    0.686       0.286                  0.340
# 2            0.868    0.683       0.284                  0.408
# 3            0.914    0.677       0.353                  0.138
# 4            0.927    0.660       0.256                  0.357

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
null_values_2018 = df_2018.isnull().sum()
null_values_2018
# Out:
# happiness_rank           0
# country                  0
# happiness_score          0
# gdp_per_capita           0
# family                   0
# life_expectancy          0
# freedom                  0
# generosity               0
# government_corruption    1
# dtype: int64

# %%
df_2019 = pd.read_csv("Raw_Datasets/2019.csv")
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df_2019.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091

# %%
safe_df_2019 = df_2019.copy()

# %%
df_2019 = df_2019.rename(columns={
    "Country or region" : "country",
    "Overall rank" : "happiness_rank",
    "Score" : "happiness_score",
    "GDP per capita" : "gdp_per_capita",
    "Social support" : "family",
    "Healthy life expectancy" : "life_expectancy",
    "Freedom to make life choices" : "freedom",
    "Perceptions of corruption": "government_corruption",
    "Generosity": "generosity",
})

df_2019.head()
# Out:
#    happiness_rank      country  happiness_score  gdp_per_capita  family  \
# 0               1      Finland            7.769           1.340   1.587
# 1               2      Denmark            7.600           1.383   1.573
# 2               3       Norway            7.554           1.488   1.582
# 3               4      Iceland            7.494           1.380   1.624
# 4               5  Netherlands            7.488           1.396   1.522
#
#    life_expectancy  freedom  generosity  government_corruption
# 0            0.986    0.596       0.153                  0.393
# 1            0.996    0.592       0.252                  0.410
# 2            1.028    0.603       0.271                  0.341
# 3            1.026    0.591       0.354                  0.118
# 4            0.999    0.557       0.322                  0.298

# %%
null_values_2019 = df_2019.isnull().sum()
null_values_2019
# Out:
# happiness_rank           0
# country                  0
# happiness_score          0
# gdp_per_capita           0
# family                   0
# life_expectancy          0
# freedom                  0
# generosity               0
# government_corruption    0
# dtype: int64

# %%
df_2019.tail()
# Out:
#      happiness_rank                   country  happiness_score  \
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      gdp_per_capita  family  life_expectancy  freedom  generosity  \
# 151           0.359   0.711            0.614    0.555       0.217
# 152           0.476   0.885            0.499    0.417       0.276
# 153           0.350   0.517            0.361    0.000       0.158
# 154           0.026   0.000            0.105    0.225       0.235
# 155           0.306   0.575            0.295    0.010       0.202
#
#      government_corruption
# 151                  0.411
# 152                  0.147
# 153                  0.025
# 154                  0.035
# 155                  0.091

# %%
# function to reorder the columns so that we concat everything will be in place

def reorder_columns(df, column_order):
    # Insures that every column exists (if there is something missing adds NaN
    for col in column_order:
        if col not in df.columns:
            df[col] = None  

    # Reorders the columns
    return df[column_order]

# %%
standard_columns = [
    'country','happiness_rank', 'happiness_score',
    'gdp_per_capita', 'family', 'life_expectancy', 'freedom',
    'government_corruption', 'generosity', 'dystopia_residual'
]

# %%
# reordering for every dataset

safe_df_2015 = reorder_columns(df_2015, standard_columns)
df_2015.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard_error  gdp_per_capita   family  life_expectancy  freedom  \
# 0         0.03411         1.39651  1.34951          0.94143  0.66557
# 1         0.04884         1.30232  1.40223          0.94784  0.62877
# 2         0.03328         1.32548  1.36058          0.87464  0.64938
# 3         0.03880         1.45900  1.33095          0.88521  0.66973
# 4         0.03553         1.32629  1.32261          0.90563  0.63297
#
#    government_corruption  generosity  dystopia_residual
# 0                0.41978     0.29678            2.51738
# 1                0.14145     0.43630            2.70201
# 2                0.48357     0.34139            2.49204
# 3                0.36503     0.34699            2.46531
# 4                0.32957     0.45811            2.45176

# %%
print(df_2015.columns)
# Out:
# Index(['country', 'region', 'happiness_rank', 'happiness_score',
#        'standard_error', 'gdp_per_capita', 'family', 'life_expectancy',
#        'freedom', 'government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
# droping columns that don't add much information and that the others datasets don't have

df_2015 = df_2015.drop(columns=["region", "standard_error"])
df_2015.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita   family  \
# 0  Switzerland               1            7.587         1.39651  1.34951
# 1      Iceland               2            7.561         1.30232  1.40223
# 2      Denmark               3            7.527         1.32548  1.36058
# 3       Norway               4            7.522         1.45900  1.33095
# 4       Canada               5            7.427         1.32629  1.32261
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0          0.94143  0.66557                0.41978     0.29678
# 1          0.94784  0.62877                0.14145     0.43630
# 2          0.87464  0.64938                0.48357     0.34139
# 3          0.88521  0.66973                0.36503     0.34699
# 4          0.90563  0.63297                0.32957     0.45811
#
#    dystopia_residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
df_2016 = reorder_columns(df_2016, standard_columns)
df_2016.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita   family  \
# 0      Denmark               1            7.526         1.44178  1.16374
# 1  Switzerland               2            7.509         1.52733  1.14524
# 2      Iceland               3            7.501         1.42666  1.18326
# 3       Norway               4            7.498         1.57744  1.12690
# 4      Finland               5            7.413         1.40598  1.13464
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0          0.79504  0.57941                0.44453     0.36171
# 1          0.86303  0.58557                0.41203     0.28083
# 2          0.86733  0.56624                0.14975     0.47678
# 3          0.79579  0.59609                0.35776     0.37895
# 4          0.81091  0.57104                0.41004     0.25492
#
#    dystopia_residual
# 0            2.73939
# 1            2.69463
# 2            2.83137
# 3            2.66465
# 4            2.82596

# %%
df_2017 = reorder_columns(df_2017, standard_columns)
df_2017.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita    family  \
# 0       Norway               1            7.537        1.616463  1.533524
# 1      Denmark               2            7.522        1.482383  1.551122
# 2      Iceland               3            7.504        1.480633  1.610574
# 3  Switzerland               4            7.494        1.564980  1.516912
# 4      Finland               5            7.469        1.443572  1.540247
#
#    life_expectancy   freedom  government_corruption  generosity  \
# 0         0.796667  0.635423               0.315964    0.362012
# 1         0.792566  0.626007               0.400770    0.355280
# 2         0.833552  0.627163               0.153527    0.475540
# 3         0.858131  0.620071               0.367007    0.290549
# 4         0.809158  0.617951               0.382612    0.245483
#
#    dystopia_residual
# 0           2.277027
# 1           2.313707
# 2           2.322715
# 3           2.276716
# 4           2.430182

# %%
df_2018 = reorder_columns(df_2018, standard_columns)
df_2018.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita  family  \
# 0      Finland               1            7.632           1.305   1.592
# 1       Norway               2            7.594           1.456   1.582
# 2      Denmark               3            7.555           1.351   1.590
# 3      Iceland               4            7.495           1.343   1.644
# 4  Switzerland               5            7.487           1.420   1.549
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0            0.874    0.681                  0.393       0.202
# 1            0.861    0.686                  0.340       0.286
# 2            0.868    0.683                  0.408       0.284
# 3            0.914    0.677                  0.138       0.353
# 4            0.927    0.660                  0.357       0.256
#
#   dystopia_residual
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None

# %%
df_2019 = reorder_columns(df_2019, standard_columns)
df_2019.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita  family  \
# 0      Finland               1            7.769           1.340   1.587
# 1      Denmark               2            7.600           1.383   1.573
# 2       Norway               3            7.554           1.488   1.582
# 3      Iceland               4            7.494           1.380   1.624
# 4  Netherlands               5            7.488           1.396   1.522
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0            0.986    0.596                  0.393       0.153
# 1            0.996    0.592                  0.410       0.252
# 2            1.028    0.603                  0.341       0.271
# 3            1.026    0.591                  0.118       0.354
# 4            0.999    0.557                  0.298       0.322
#
#   dystopia_residual
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None

# %%
df_2015['year'] = 2015
df_2016['year'] = 2016
df_2017['year'] = 2017
df_2018['year'] = 2018
df_2019['year'] = 2019

# %%
df_2015.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita   family  \
# 0  Switzerland               1            7.587         1.39651  1.34951
# 1      Iceland               2            7.561         1.30232  1.40223
# 2      Denmark               3            7.527         1.32548  1.36058
# 3       Norway               4            7.522         1.45900  1.33095
# 4       Canada               5            7.427         1.32629  1.32261
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0          0.94143  0.66557                0.41978     0.29678
# 1          0.94784  0.62877                0.14145     0.43630
# 2          0.87464  0.64938                0.48357     0.34139
# 3          0.88521  0.66973                0.36503     0.34699
# 4          0.90563  0.63297                0.32957     0.45811
#
#    dystopia_residual  year
# 0            2.51738  2015
# 1            2.70201  2015
# 2            2.49204  2015
# 3            2.46531  2015
# 4            2.45176  2015

# %%
df_2019.head()
# Out:
#        country  happiness_rank  happiness_score  gdp_per_capita  family  \
# 0      Finland               1            7.769           1.340   1.587
# 1      Denmark               2            7.600           1.383   1.573
# 2       Norway               3            7.554           1.488   1.582
# 3      Iceland               4            7.494           1.380   1.624
# 4  Netherlands               5            7.488           1.396   1.522
#
#    life_expectancy  freedom  government_corruption  generosity  \
# 0            0.986    0.596                  0.393       0.153
# 1            0.996    0.592                  0.410       0.252
# 2            1.028    0.603                  0.341       0.271
# 3            1.026    0.591                  0.118       0.354
# 4            0.999    0.557                  0.298       0.322
#
#   dystopia_residual  year
# 0              None  2019
# 1              None  2019
# 2              None  2019
# 3              None  2019
# 4              None  2019

# %% [markdown]
# # **2. This part of the code will save the 5 datasets as csv files**

# %%
import os

# adding a new folder named Clean_Datasets
output_folder = "Clean_Datasets"
os.makedirs(output_folder, exist_ok=True)

# %%
#

dfs_by_year = {
    2015: df_2015,
    2016: df_2016,
    2017: df_2017,
    2018: df_2018,
    2019: df_2019
}

# Saves each dataset in to csv files in a specific folder
for year, df in dfs_by_year.items():
    output_path = os.path.join(output_folder, f"clean_{year}.csv")
    df.to_csv(output_path, index=False)
    print(f"Saved: {output_path}")
# Out:
# Saved: Clean_Datasets\clean_2015.csv
# Saved: Clean_Datasets\clean_2016.csv
# Saved: Clean_Datasets\clean_2017.csv
# Saved: Clean_Datasets\clean_2018.csv
# Saved: Clean_Datasets\clean_2019.csv

# %% [markdown]
# # **3. Merging the datasets in one**
# ```

# %%
final_df = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)

cols = final_df.columns.tolist()
cols.remove('year')
final_df = final_df[['year'] + cols]

final_df.to_csv("world_happyiness_5_years.csv", index=False)

final_df.head()
# Out:
# C:\Users\Naveen\AppData\Local\Temp\ipykernel_14092\2817207272.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)
#    year      country  happiness_rank  happiness_score  gdp_per_capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#     family  life_expectancy  freedom  government_corruption  generosity  \
# 0  1.34951          0.94143  0.66557                0.41978     0.29678
# 1  1.40223          0.94784  0.62877                0.14145     0.43630
# 2  1.36058          0.87464  0.64938                0.48357     0.34139
# 3  1.33095          0.88521  0.66973                0.36503     0.34699
# 4  1.32261          0.90563  0.63297                0.32957     0.45811
#
#    dystopia_residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
# final_df = final_df.drop(columns=["gdp_per_capita"])
# final_df.head()

# %%
final_df
# Out:
#      year                   country  happiness_rank  happiness_score  \
# 0    2015               Switzerland               1            7.587
# 1    2015                   Iceland               2            7.561
# 2    2015                   Denmark               3            7.527
# 3    2015                    Norway               4            7.522
# 4    2015                    Canada               5            7.427
# ..    ...                       ...             ...              ...
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      gdp_per_capita   family  life_expectancy  freedom  government_corruption  \
# 0           1.39651  1.34951          0.94143  0.66557                0.41978
# 1           1.30232  1.40223          0.94784  0.62877                0.14145
# 2           1.32548  1.36058          0.87464  0.64938                0.48357
# 3           1.45900  1.33095          0.88521  0.66973                0.36503
# 4           1.32629  1.32261          0.90563  0.63297                0.32957
# ..              ...      ...              ...      ...                    ...
# 777         0.35900  0.71100          0.61400  0.55500                0.41100
# 778         0.47600  0.88500          0.49900  0.41700                0.14700
# 779         0.35000  0.51700          0.36100  0.00000                0.02500
# 780         0.02600  0.00000          0.10500  0.22500                0.03500
# 781         0.30600  0.57500          0.29500  0.01000                0.09100
#
#      generosity  dystopia_residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 777     0.21700                NaN
# 778     0.27600                NaN
# 779     0.15800                NaN
# 780     0.23500                NaN
# 781     0.20200                NaN
#
# [782 rows x 11 columns]

# %%
safe_final_df = final_df.copy()

# %%
final_df_null = final_df.isnull().sum()
final_df_null
# Out:
# year                       0
# country                    0
# happiness_rank             0
# happiness_score            0
# gdp_per_capita             0
# family                     0
# life_expectancy            0
# freedom                    0
# government_corruption      1
# generosity                 0
# dystopia_residual        312
# dtype: int64

# %%
final_df.describe()
# Out:
#               year  happiness_rank  happiness_score  gdp_per_capita  \
# count   782.000000      782.000000       782.000000      782.000000
# mean   2016.993606       78.698210         5.379018        0.916047
# std       1.417364       45.182384         1.127456        0.407340
# min    2015.000000        1.000000         2.693000        0.000000
# 25%    2016.000000       40.000000         4.509750        0.606500
# 50%    2017.000000       79.000000         5.322000        0.982205
# 75%    2018.000000      118.000000         6.189500        1.236187
# max    2019.000000      158.000000         7.769000        2.096000
#
#            family  life_expectancy     freedom  government_corruption  \
# count  782.000000       782.000000  782.000000             781.000000
# mean     1.078392         0.612416    0.411091               0.125436
# std      0.329548         0.248309    0.152880               0.105816
# min      0.000000         0.000000    0.000000               0.000000
# 25%      0.869363         0.440183    0.309768               0.054000
# 50%      1.124735         0.647310    0.431000               0.091000
# 75%      1.327250         0.808000    0.531000               0.156030
# max      1.644000         1.141000    0.724000               0.551910
#
#        generosity  dystopia_residual
# count  782.000000         470.000000
# mean     0.218576           2.092717
# std      0.122321           0.565772
# min      0.000000           0.328580
# 25%      0.130000           1.737975
# 50%      0.201982           2.094640
# 75%      0.278832           2.455575
# max      0.838075           3.837720

# %%
final_df.value_counts()
# Out:
# year  country         happiness_rank  happiness_score  gdp_per_capita  family    life_expectancy  freedom   government_corruption  generosity  dystopia_residual
# 2015  Afghanistan     153             3.575            0.319820        0.302850  0.303350         0.234140  0.097190               0.365100    1.952100             1
# 2016  Uzbekistan      49              5.987            0.735910        1.168100  0.501630         0.608480  0.283330               0.343260    2.346380             1
# 2017  Australia       10              7.284            1.484415        1.510042  0.843887         0.601607  0.301184               0.477699    2.065211             1
#       Armenia         121             4.376            0.900597        1.007484  0.637524         0.198303  0.026674               0.083488    1.521499             1
#       Argentina       24              6.599            1.185295        1.440451  0.695137         0.494519  0.059740               0.109457    2.614005             1
#                                                                                                                                                                    ..
# 2015  Uzbekistan      44              6.003            0.632440        1.340430  0.597720         0.658210  0.308260               0.228370    2.237410             1
#       Uruguay         32              6.485            1.061660        1.208900  0.811600         0.603620  0.245580               0.232400    2.321420             1
#       United States   15              7.119            1.394510        1.247110  0.861790         0.546040  0.158900               0.401050    2.510110             1
#       United Kingdom  21              6.867            1.266370        1.285480  0.909430         0.596250  0.320670               0.519120    1.969940             1
# 2017  Zimbabwe        138             3.875            0.375847        1.083096  0.196764         0.336384  0.095375               0.189143    1.597970             1
# Name: count, Length: 470, dtype: int64

# %%
final_df.shape
# Out:
# (782, 11)

# %%
final_df.nunique()
# Out:
# year                       5
# country                  170
# happiness_rank           158
# happiness_score          716
# gdp_per_capita           742
# family                   732
# life_expectancy          705
# freedom                  697
# government_corruption    635
# generosity               664
# dystopia_residual        470
# dtype: int64

# %%
final_df.isnull().sum()
# Out:
# year                       0
# country                    0
# happiness_rank             0
# happiness_score            0
# gdp_per_capita             0
# family                     0
# life_expectancy            0
# freedom                    0
# government_corruption      1
# generosity                 0
# dystopia_residual        312
# dtype: int64

# %%
df_countries = final_df[['country']].drop_duplicates().reset_index(drop=True)
df_countries['country_id'] = df_countries.index + 1  
final_df = final_df.merge(df_countries, on='country', how='left')

# %%
final_df.head()
# Out:
#    year      country  happiness_rank  happiness_score  gdp_per_capita  \
# 0  2015  Switzerland               1            7.587         1.39651
# 1  2015      Iceland               2            7.561         1.30232
# 2  2015      Denmark               3            7.527         1.32548
# 3  2015       Norway               4            7.522         1.45900
# 4  2015       Canada               5            7.427         1.32629
#
#     family  life_expectancy  freedom  government_corruption  generosity  \
# 0  1.34951          0.94143  0.66557                0.41978     0.29678
# 1  1.40223          0.94784  0.62877                0.14145     0.43630
# 2  1.36058          0.87464  0.64938                0.48357     0.34139
# 3  1.33095          0.88521  0.66973                0.36503     0.34699
# 4  1.32261          0.90563  0.63297                0.32957     0.45811
#
#    dystopia_residual  country_id
# 0            2.51738           1
# 1            2.70201           2
# 2            2.49204           3
# 3            2.46531           4
# 4            2.45176           5

# %%
final_df
# Out:
#      year                   country  happiness_rank  happiness_score  \
# 0    2015               Switzerland               1            7.587
# 1    2015                   Iceland               2            7.561
# 2    2015                   Denmark               3            7.527
# 3    2015                    Norway               4            7.522
# 4    2015                    Canada               5            7.427
# ..    ...                       ...             ...              ...
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      gdp_per_capita   family  life_expectancy  freedom  government_corruption  \
# 0           1.39651  1.34951          0.94143  0.66557                0.41978
# 1           1.30232  1.40223          0.94784  0.62877                0.14145
# 2           1.32548  1.36058          0.87464  0.64938                0.48357
# 3           1.45900  1.33095          0.88521  0.66973                0.36503
# 4           1.32629  1.32261          0.90563  0.63297                0.32957
# ..              ...      ...              ...      ...                    ...
# 777         0.35900  0.71100          0.61400  0.55500                0.41100
# 778         0.47600  0.88500          0.49900  0.41700                0.14700
# 779         0.35000  0.51700          0.36100  0.00000                0.02500
# 780         0.02600  0.00000          0.10500  0.22500                0.03500
# 781         0.30600  0.57500          0.29500  0.01000                0.09100
#
#      generosity  dystopia_residual  country_id
# 0       0.29678            2.51738           1
# 1       0.43630            2.70201           2
# 2       0.34139            2.49204           3
# 3       0.34699            2.46531           4
# 4       0.45811            2.45176           5
# ..          ...                ...         ...
# 777     0.21700                NaN         154
# 778     0.27600                NaN         146
# 779     0.15800                NaN         153
# 780     0.23500                NaN         148
# 781     0.20200                NaN         164
#
# [782 rows x 12 columns]

# %%
df_factors = final_df[[
    'year', 'family', 'life_expectancy', 'freedom',
    'government_corruption', 'generosity', 'dystopia_residual',
    'gdp_per_capita', 'happiness_rank', 'happiness_score', 'country_id'
]]
df_factors.to_csv("factors_ready.csv", index=False)

# %%
df_countries.to_csv("countries.csv", index=False)

df_countries.head()
# Out:
#        country  country_id
# 0  Switzerland           1
# 1      Iceland           2
# 2      Denmark           3
# 3       Norway           4
# 4       Canada           5

# %%
df_countries.shape
# Out:
# (170, 2)

# %%
final_df[final_df['dystopia_residual'].isnull()]
# Out:
#      year                   country  happiness_rank  happiness_score  \
# 470  2018                   Finland               1            7.632
# 471  2018                    Norway               2            7.594
# 472  2018                   Denmark               3            7.555
# 473  2018                   Iceland               4            7.495
# 474  2018               Switzerland               5            7.487
# ..    ...                       ...             ...              ...
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      gdp_per_capita  family  life_expectancy  freedom  government_corruption  \
# 470           1.305   1.592            0.874    0.681                  0.393
# 471           1.456   1.582            0.861    0.686                  0.340
# 472           1.351   1.590            0.868    0.683                  0.408
# 473           1.343   1.644            0.914    0.677                  0.138
# 474           1.420   1.549            0.927    0.660                  0.357
# ..              ...     ...              ...      ...                    ...
# 777           0.359   0.711            0.614    0.555                  0.411
# 778           0.476   0.885            0.499    0.417                  0.147
# 779           0.350   0.517            0.361    0.000                  0.025
# 780           0.026   0.000            0.105    0.225                  0.035
# 781           0.306   0.575            0.295    0.010                  0.091
#
#      generosity  dystopia_residual  country_id
# 470       0.202                NaN           6
# 471       0.286                NaN           4
# 472       0.284                NaN           3
# 473       0.353                NaN           2
# 474       0.256                NaN           1
# ..          ...                ...         ...
# 777       0.217                NaN         154
# 778       0.276                NaN         146
# 779       0.158                NaN         153
# 780       0.235                NaN         148
# 781       0.202                NaN         164
#
# [312 rows x 12 columns]

# %%
final_df['dystopia_residual'] = final_df['happiness_score'] - (
    final_df['gdp_per_capita'] +
    final_df['family'] +
    final_df['life_expectancy'] +
    final_df['freedom'] +
    final_df['government_corruption'] +
    final_df['generosity']
)

# %%
final_df.tail()
# Out:
#      year                   country  happiness_rank  happiness_score  \
# 777  2019                    Rwanda             152            3.334
# 778  2019                  Tanzania             153            3.231
# 779  2019               Afghanistan             154            3.203
# 780  2019  Central African Republic             155            3.083
# 781  2019               South Sudan             156            2.853
#
#      gdp_per_capita  family  life_expectancy  freedom  government_corruption  \
# 777           0.359   0.711            0.614    0.555                  0.411
# 778           0.476   0.885            0.499    0.417                  0.147
# 779           0.350   0.517            0.361    0.000                  0.025
# 780           0.026   0.000            0.105    0.225                  0.035
# 781           0.306   0.575            0.295    0.010                  0.091
#
#      generosity  dystopia_residual  country_id
# 777       0.217              0.467         154
# 778       0.276              0.531         146
# 779       0.158              1.792         153
# 780       0.235              2.457         148
# 781       0.202              1.374         164

# %%
df_factors = final_df[[
    'year', 'family', 'life_expectancy', 'freedom',
    'government_corruption', 'generosity', 'dystopia_residual',
    'gdp_per_capita', 'happiness_rank', 'happiness_score', 'country_id'
]]
df_factors.to_csv("factors_ready.csv", index=False)

# %%
df_factors.tail()
# Out:
#      year  family  life_expectancy  freedom  government_corruption  \
# 777  2019   0.711            0.614    0.555                  0.411
# 778  2019   0.885            0.499    0.417                  0.147
# 779  2019   0.517            0.361    0.000                  0.025
# 780  2019   0.000            0.105    0.225                  0.035
# 781  2019   0.575            0.295    0.010                  0.091
#
#      generosity  dystopia_residual  gdp_per_capita  happiness_rank  \
# 777       0.217              0.467           0.359             152
# 778       0.276              0.531           0.476             153
# 779       0.158              1.792           0.350             154
# 780       0.235              2.457           0.026             155
# 781       0.202              1.374           0.306             156
#
#      happiness_score  country_id
# 777            3.334         154
# 778            3.231         146
# 779            3.203         153
# 780            3.083         148
# 781            2.853         164

# %%
df_factors.isnull().sum()
# Out:
# year                     0
# family                   0
# life_expectancy          0
# freedom                  0
# government_corruption    1
# generosity               0
# dystopia_residual        1
# gdp_per_capita           0
# happiness_rank           0
# happiness_score          0
# country_id               0
# dtype: int64

# %%
df_factors[df_factors['dystopia_residual'].isnull()]
# Out:
#      year  family  life_expectancy  freedom  government_corruption  \
# 489  2018   0.776             0.67    0.284                    NaN
#
#      generosity  dystopia_residual  gdp_per_capita  happiness_rank  \
# 489       0.186                NaN           2.096              20
#
#      happiness_score  country_id
# 489            6.774          20

# %% [markdown]
# GRAPH FOR YEAR AND IMPORTANT FACTORS

# %%
year_factor = pd.read_csv("average_factors_by_year.csv")
year_factor
# Out:
#    year  avg_gdp  avg_fam  avg_le  avg_free  avg_govcorr  avg_gen
# 0  2015    0.846    0.991   0.630     0.429        0.143    0.237
# 1  2016    0.954    0.794   0.558     0.371        0.138    0.243
# 2  2017    0.985    1.189   0.551     0.409        0.123    0.247
# 3  2018    0.884    1.216   0.597     0.456        0.112    0.181
# 4  2019    0.905    1.209   0.725     0.393        0.111    0.185

# %%
import matplotlib.pyplot as plt
import seaborn as sns

metrics = ["avg_gdp", "avg_fam", "avg_le", "avg_free", "avg_govcorr", "avg_gen"]
for metric in metrics:
    plt.figure()
    plt.bar(year_factor["year"], year_factor[metric], color="blue")
    plt.title(f"{metric.replace('_', ' ').title()} Over Years")
    plt.xlabel("Year")
    plt.ylabel("Value")
    plt.xticks(year_factor["year"])
    plt.tight_layout()
    plt.show()

# %%
bar_width = 0.12
years = year_factor["year"]
x = range(len(years))
plt.figure(figsize=(12, 6))

for i, column in enumerate(year_factor.columns[1:]):
    plt.bar(
        [pos + bar_width * i for pos in x],
        year_factor[column],
        width=bar_width,
        label=column
    )

plt.xticks([pos + bar_width * 2.5 for pos in x], years)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("All Metrics Over Years")
plt.legend()
plt.tight_layout()

plt.show()

# %%
gdp_family = pd.read_csv("GDP_FAMILY_by_country.csv")
gdp_family
# Out:
#              country  avg_gdp  avg_fam
# 0            Iceland    1.387    1.493
# 1  Trinidad & Tobago    1.227    1.484
# 2            Denmark    1.397    1.448
# 3            Ireland    1.460    1.445
# 4        New Zealand    1.318    1.440
# 5            Finland    1.357    1.434
# 6         Uzbekistan    0.724    1.434
# 7             Norway    1.519    1.431
# 8        Switzerland    1.472    1.417
# 9          Australia    1.395    1.409

# %%
plt.figure(figsize=(10, 6))

# Scatter plot with regression line
sns.regplot(data=gdp_family, x='avg_gdp', y='avg_fam', scatter=True, color='blue', line_kws={"color": "red"})

# Add country labels at each point
for i in range(len(gdp_family)):
    plt.text(gdp_family['avg_gdp'][i] + 0.005, gdp_family['avg_fam'][i] + 0.002, gdp_family['country'][i],
             fontsize=9, ha='left', va='bottom')

# Set labels and title
plt.xlabel('Average GDP')
plt.ylabel('Average Family Score')
plt.title('Higher level countries in Average Family Score ')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
fam = pd.read_csv("GDP_FAMILY_ASC_by_country.csv")
fam
# Out:
#                     country  avg_gdp  avg_fam
# 0  Central African Republic    0.032    0.000
# 1                      Togo    0.266    0.324
# 2                     Benin    0.377    0.340
# 3                     Syria    0.699    0.356
# 4               Afghanistan    0.357    0.410
# 5                    Malawi    0.143    0.434
# 6                   Burundi    0.062    0.471
# 7                   Georgia    0.854    0.481
# 8               South Sudan    0.359    0.492
# 9                     India    0.731    0.588

# %%
plt.figure(figsize=(10, 6))

# Scatter plot with regression line
sns.regplot(data=fam, x='avg_gdp', y='avg_fam', scatter=True, color='darkgreen', line_kws={"color": "blue"})

# Add country labels at each point
for i in range(len(fam)):
    plt.text(fam['avg_gdp'][i] + 0.005, fam['avg_fam'][i] + 0.002, fam['country'][i],
             fontsize=9, ha='left', va='bottom')

# Set labels and title
plt.xlabel('Average GDP')
plt.ylabel('Average Family Score')
plt.title('Lower level countries in Average Family Score ')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
